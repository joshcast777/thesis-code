# %% [markdown]
# # Copying sample to population

# %%
# Import libraries

import pandas as pd
import re

# %%
# Function to count records

def show_record_count(df):
	"""Display the total number of records in a DataFrame.

	Args:
		df (pandas.DataFrame): The DataFrame for which the number of records will be displayed.

	Returns:
		str: A string indicating the total number of records in the DataFrame.
	"""

	return f"Total records: {len(df)}"

# %%
# Constants

# Paths
DATA_PATH = "data/"
"""str: Path for the data."""

# File names
CORPUS_POPULATION_FILE = "CORPUS_POPULATION"
"""str: Name of the corpus population file created."""

POPULATION_SEPARATED_FILE = "POPULATION_SEPARATED"
"""str: Name of the population_separated file."""

SAMPLE_FILE = "SAMPLE"
"""str: Name of the sample file."""

CORPUS_SAMPLE_FILE = "CORPUS_SAMPLE"
"""str: Name of the corpus_sample file."""

# Fields
SNT_ID_FIELD = "snt_id"
"""str: Name of the snt_id field."""

GPT_COMPLEX_WORD_FIELD = "complex_word_gpt3"
"""str: Name of the complex_word_gpt3 field."""

QUERY_TEXT_FIELD = "query_text"
"""str: Name of the query_text field"""
# Out:
# 'str: Name of the query_text field'

# %% [markdown]
# ## Formatting sample

# %%
sample = pd.read_excel(f"{DATA_PATH}{SAMPLE_FILE}.xlsx", sheet_name=SAMPLE_FILE)

print(show_record_count(sample[SNT_ID_FIELD]))

sample.head()
# Out:
# Total records: 589
#                snt_id             query_text  \
# 0  G14.2_2884788726_2  end to end encryption
# 1                 NaN                    NaN
# 2                 NaN                    NaN
# 3                 NaN                    NaN
# 4  G17.2_2893955699_1                   qbit
#
#                                      source_snt_comp  \
# 0  However, in information-centric networking (IC...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Concatenated Greenberger–Horne–Zeilinger (...
#
#                       complex_word_gpt3  difficulty_gpt3  \
# 0                 End-to-End Encryption              2.0
# 1                        Encryption Key              2.0
# 2  Information-Centric Networking (ICN)              1.0
# 3                       Content Caching              0.0
# 4                                 qubit              1.0
#
#                                      definition_gpt3  \
# 0  A method whereby data is encrypted before it i...
# 1            A key used to encrypt and decrypt data.
# 2  A type of network architecture in which the da...
# 3  A method whereby data is stored on an intermed...
# 4  A qubit is a unit of quantum information, whic...
#
#                                         example_gpt3  \
# 0   Sending a message via an encrypted messaging app
# 1  A key used to encrypt a message before it is sent
# 2  A network where data is stored in caches and c...
# 3  Downloading a web page from a local server ins...
# 4                An electron can be used as a qubit.
#
#                                        use_case_gpt3
# 0  To protect sensitive data, such as financial i...
# 1                              To protect data from.
# 2  Caching data to improve access speed and relia...
# 3  To improve access speed and reduce bandwidth u...
# 4  Qubits are used in quantum computing to store ...

# %%
# Fill the snt_id column

for col in sample.columns[:3]:
  value = None

  for i, current_value in enumerate(sample[col]):
    if pd.notna(current_value):
      value = current_value
    else:
      sample[col][i] = value

print(show_record_count(sample[SNT_ID_FIELD]))

sample.head()
# Out:
# <ipython-input-21-73fc60df7b3b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample[col][i] = value
# Total records: 589
#                snt_id             query_text  \
# 0  G14.2_2884788726_2  end to end encryption
# 1  G14.2_2884788726_2  end to end encryption
# 2  G14.2_2884788726_2  end to end encryption
# 3  G14.2_2884788726_2  end to end encryption
# 4  G17.2_2893955699_1                   qbit
#
#                                      source_snt_comp  \
# 0  However, in information-centric networking (IC...
# 1  However, in information-centric networking (IC...
# 2  However, in information-centric networking (IC...
# 3  However, in information-centric networking (IC...
# 4  Concatenated Greenberger–Horne–Zeilinger (...
#
#                       complex_word_gpt3  difficulty_gpt3  \
# 0                 End-to-End Encryption              2.0
# 1                        Encryption Key              2.0
# 2  Information-Centric Networking (ICN)              1.0
# 3                       Content Caching              0.0
# 4                                 qubit              1.0
#
#                                      definition_gpt3  \
# 0  A method whereby data is encrypted before it i...
# 1            A key used to encrypt and decrypt data.
# 2  A type of network architecture in which the da...
# 3  A method whereby data is stored on an intermed...
# 4  A qubit is a unit of quantum information, whic...
#
#                                         example_gpt3  \
# 0   Sending a message via an encrypted messaging app
# 1  A key used to encrypt a message before it is sent
# 2  A network where data is stored in caches and c...
# 3  Downloading a web page from a local server ins...
# 4                An electron can be used as a qubit.
#
#                                        use_case_gpt3
# 0  To protect sensitive data, such as financial i...
# 1                              To protect data from.
# 2  Caching data to improve access speed and relia...
# 3  To improve access speed and reduce bandwidth u...
# 4  Qubits are used in quantum computing to store ...

# %%
# Export as an Excel

sample.to_excel(f"{DATA_PATH}{CORPUS_SAMPLE_FILE}.xlsx", sheet_name=SAMPLE_FILE, index=False)

# %% [markdown]
# ## Comparing Sample with Population and concatenating

# %%
# Reading Excel files

population = pd.read_excel(f"{DATA_PATH}{POPULATION_SEPARATED_FILE}.xlsx", sheet_name=POPULATION_SEPARATED_FILE)
sample = pd.read_excel(f"{DATA_PATH}{CORPUS_SAMPLE_FILE}.xlsx", sheet_name=SAMPLE_FILE)

# %%
print(show_record_count(population[SNT_ID_FIELD]))

population.head()
# Out:
# Total records: 9017
#    Unnamed: 0              snt_id query_text  \
# 0           0  G11.1_2892036907_1     drones
# 1           1  G11.1_2892036907_1     drones
# 2           2  G11.1_2892036907_1     drones
# 3           3  G11.1_2892036907_1     drones
# 4           4  G11.1_2892036907_1     drones
#
#                                           source_snt complex_word_gpt3  \
# 0  In the modern era of automation and robotics, ...        Autonomous
# 1  In the modern era of automation and robotics, ...          Robotics
# 2  In the modern era of automation and robotics, ...        Automation
# 3  In the modern era of automation and robotics, ...          Academic
# 4  In the modern era of automation and robotics, ...        Industrial
#
#    difficulty_gpt3                                    definition_gpt3  \
# 0                1  able to act independently without requiring di...
# 1                1  the science and technology of robots, their de...
# 2                1  the use of technology to automate tasks that w...
# 3                0  of or relating to education or study at a scho...
# 4                0  relating to or involving the industry or manuf...
#
#                                         example_gpt3  \
# 0   Autonomous vehicles can navigate roads withou...
# 1   Robotics is used to automate tasks that would...
# 2   Automation can be used to control the speed a...
# 3   Academic research is conducted at universitie...
# 4   Industrial robots are used in manufacturing s...
#
#                                        use_case_gpt3
# 0   Autonomous vehicles can be used to deliver go...
# 1   Robotics can be used in factories to assemble...
# 2   Automation can be used in production lines to...
# 3   Academic research can provide valuable insigh...
# 4                                                NaN

# %%
print(show_record_count(sample[SNT_ID_FIELD]))

sample.head()
# Out:
# Total records: 589
#                snt_id             query_text  \
# 0  G14.2_2884788726_2  end to end encryption
# 1  G14.2_2884788726_2  end to end encryption
# 2  G14.2_2884788726_2  end to end encryption
# 3  G14.2_2884788726_2  end to end encryption
# 4  G17.2_2893955699_1                   qbit
#
#                                      source_snt_comp  \
# 0  However, in information-centric networking (IC...
# 1  However, in information-centric networking (IC...
# 2  However, in information-centric networking (IC...
# 3  However, in information-centric networking (IC...
# 4  Concatenated Greenberger–Horne–Zeilinger (...
#
#                       complex_word_gpt3  difficulty_gpt3  \
# 0                 End-to-End Encryption              2.0
# 1                        Encryption Key              2.0
# 2  Information-Centric Networking (ICN)              1.0
# 3                       Content Caching              0.0
# 4                                 qubit              1.0
#
#                                      definition_gpt3  \
# 0  A method whereby data is encrypted before it i...
# 1            A key used to encrypt and decrypt data.
# 2  A type of network architecture in which the da...
# 3  A method whereby data is stored on an intermed...
# 4  A qubit is a unit of quantum information, whic...
#
#                                         example_gpt3  \
# 0   Sending a message via an encrypted messaging app
# 1  A key used to encrypt a message before it is sent
# 2  A network where data is stored in caches and c...
# 3  Downloading a web page from a local server ins...
# 4                An electron can be used as a qubit.
#
#                                        use_case_gpt3
# 0  To protect sensitive data, such as financial i...
# 1                              To protect data from.
# 2  Caching data to improve access speed and relia...
# 3  To improve access speed and reduce bandwidth u...
# 4  Qubits are used in quantum computing to store ...

# %%
# Format data

population[GPT_COMPLEX_WORD_FIELD] = population[GPT_COMPLEX_WORD_FIELD].str.capitalize()
sample[GPT_COMPLEX_WORD_FIELD] = sample[GPT_COMPLEX_WORD_FIELD].str.capitalize()

# %%
print(show_record_count(population[SNT_ID_FIELD]))

population.head()
# Out:
# Total records: 9017
#    Unnamed: 0              snt_id query_text  \
# 0           0  G11.1_2892036907_1     drones
# 1           1  G11.1_2892036907_1     drones
# 2           2  G11.1_2892036907_1     drones
# 3           3  G11.1_2892036907_1     drones
# 4           4  G11.1_2892036907_1     drones
#
#                                           source_snt complex_word_gpt3  \
# 0  In the modern era of automation and robotics, ...        Autonomous
# 1  In the modern era of automation and robotics, ...          Robotics
# 2  In the modern era of automation and robotics, ...        Automation
# 3  In the modern era of automation and robotics, ...          Academic
# 4  In the modern era of automation and robotics, ...        Industrial
#
#    difficulty_gpt3                                    definition_gpt3  \
# 0                1  able to act independently without requiring di...
# 1                1  the science and technology of robots, their de...
# 2                1  the use of technology to automate tasks that w...
# 3                0  of or relating to education or study at a scho...
# 4                0  relating to or involving the industry or manuf...
#
#                                         example_gpt3  \
# 0   Autonomous vehicles can navigate roads withou...
# 1   Robotics is used to automate tasks that would...
# 2   Automation can be used to control the speed a...
# 3   Academic research is conducted at universitie...
# 4   Industrial robots are used in manufacturing s...
#
#                                        use_case_gpt3
# 0   Autonomous vehicles can be used to deliver go...
# 1   Robotics can be used in factories to assemble...
# 2   Automation can be used in production lines to...
# 3   Academic research can provide valuable insigh...
# 4                                                NaN

# %%
print(show_record_count(sample[SNT_ID_FIELD]))

sample.head()
# Out:
# Total records: 589
#                snt_id             query_text  \
# 0  G14.2_2884788726_2  end to end encryption
# 1  G14.2_2884788726_2  end to end encryption
# 2  G14.2_2884788726_2  end to end encryption
# 3  G14.2_2884788726_2  end to end encryption
# 4  G17.2_2893955699_1                   qbit
#
#                                      source_snt_comp  \
# 0  However, in information-centric networking (IC...
# 1  However, in information-centric networking (IC...
# 2  However, in information-centric networking (IC...
# 3  However, in information-centric networking (IC...
# 4  Concatenated Greenberger–Horne–Zeilinger (...
#
#                       complex_word_gpt3  difficulty_gpt3  \
# 0                 End-to-end encryption              2.0
# 1                        Encryption key              2.0
# 2  Information-centric networking (icn)              1.0
# 3                       Content caching              0.0
# 4                                 Qubit              1.0
#
#                                      definition_gpt3  \
# 0  A method whereby data is encrypted before it i...
# 1            A key used to encrypt and decrypt data.
# 2  A type of network architecture in which the da...
# 3  A method whereby data is stored on an intermed...
# 4  A qubit is a unit of quantum information, whic...
#
#                                         example_gpt3  \
# 0   Sending a message via an encrypted messaging app
# 1  A key used to encrypt a message before it is sent
# 2  A network where data is stored in caches and c...
# 3  Downloading a web page from a local server ins...
# 4                An electron can be used as a qubit.
#
#                                        use_case_gpt3
# 0  To protect sensitive data, such as financial i...
# 1                              To protect data from.
# 2  Caching data to improve access speed and relia...
# 3  To improve access speed and reduce bandwidth u...
# 4  Qubits are used in quantum computing to store ...

# %%
# Get SAMPLE data not repeated in POPULATION

sample_rows_not_in_population = sample[~sample.set_index([SNT_ID_FIELD, QUERY_TEXT_FIELD, GPT_COMPLEX_WORD_FIELD]).index.isin(population.set_index([SNT_ID_FIELD, QUERY_TEXT_FIELD, GPT_COMPLEX_WORD_FIELD]).index)]

def replace_none(value):
  if isinstance(value, str):
    if re.match(r'^\s*(none|none\.)\s*$', value, flags=re.IGNORECASE):
      return None

  return value

sample_rows_not_in_population = sample_rows_not_in_population.applymap(replace_none)

print(show_record_count(sample_rows_not_in_population[SNT_ID_FIELD]))

sample_rows_not_in_population.head()
# Out:
# Total records: 8
#                  snt_id            query_text  \
# 55   G17.1_2042591812_2     quantum computing
# 110  G17.4_2524344971_1  quantum applications
# 233  T16.2_1760039095_1       guessing attack
# 242  G07.2_2953000449_2   conspiracy theories
# 244  T13.3_2052300809_9       imbalanced data
#
#                                        source_snt_comp complex_word_gpt3  \
# 55   Majority gate is a fundamental Boolean operato...               NaN
# 110  Quantum entanglement can offer a quadratic enh...               NaN
# 233  Three-party key exchange protocol is one of th...   Guessing attack
# 242  global warming induced by chemtrails or the li...              None
# 244  Problems in the performance of naive Bayes on ...              None
#
#      difficulty_gpt3                                    definition_gpt3  \
# 55               NaN                                                NaN
# 110              NaN                                                NaN
# 233              2.0  A guessing attack is a type of attack in which...
# 242              NaN                                               None
# 244              NaN                                               None
#
#                                           example_gpt3  \
# 55                                                 NaN
# 110                                                NaN
# 233  A hacker attempts to guess an email address an...
# 242                                               None
# 244                                               None
#
#                                          use_case_gpt3
# 55                                                 NaN
# 110                                                NaN
# 233  Banks use guessing attack prevention methods s...
# 242                                               None
# 244                                               None

# %%
# Concat results data to ZS

population = pd.concat([population, sample_rows_not_in_population])

print(show_record_count(population[SNT_ID_FIELD]))

population.head()
# Out:
# Total records: 9025
#    Unnamed: 0              snt_id query_text  \
# 0         0.0  G11.1_2892036907_1     drones
# 1         1.0  G11.1_2892036907_1     drones
# 2         2.0  G11.1_2892036907_1     drones
# 3         3.0  G11.1_2892036907_1     drones
# 4         4.0  G11.1_2892036907_1     drones
#
#                                           source_snt complex_word_gpt3  \
# 0  In the modern era of automation and robotics, ...        Autonomous
# 1  In the modern era of automation and robotics, ...          Robotics
# 2  In the modern era of automation and robotics, ...        Automation
# 3  In the modern era of automation and robotics, ...          Academic
# 4  In the modern era of automation and robotics, ...        Industrial
#
#    difficulty_gpt3                                    definition_gpt3  \
# 0              1.0  able to act independently without requiring di...
# 1              1.0  the science and technology of robots, their de...
# 2              1.0  the use of technology to automate tasks that w...
# 3              0.0  of or relating to education or study at a scho...
# 4              0.0  relating to or involving the industry or manuf...
#
#                                         example_gpt3  \
# 0   Autonomous vehicles can navigate roads withou...
# 1   Robotics is used to automate tasks that would...
# 2   Automation can be used to control the speed a...
# 3   Academic research is conducted at universitie...
# 4   Industrial robots are used in manufacturing s...
#
#                                        use_case_gpt3 source_snt_comp
# 0   Autonomous vehicles can be used to deliver go...             NaN
# 1   Robotics can be used in factories to assemble...             NaN
# 2   Automation can be used in production lines to...             NaN
# 3   Academic research can provide valuable insigh...             NaN
# 4                                                NaN             NaN

# %%
# Export as an Excel

population.to_excel(f"{DATA_PATH}{CORPUS_POPULATION_FILE}.xlsx", sheet_name="CORPUS", index=False)
